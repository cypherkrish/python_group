# %%
print("What is your name: ")
# Out:
# What is your name:

# %%
name = input("Name:" )

# %%
print(name)
# Out:
# Krishna

# %%
name = input("Name: ")

# %%
print(name)
# Out:
# krishna

# %%
a = 10
b = 20

print(a+ b)
# Out:
# 30

# %%
a = input("A: ")
b = input("B: ")

print(a + b)
# Out:
# 1112

# %%
a = int(input("A: "))
b = int(input("B: "))

print(a + b)
# Out:
# 23

# %%
x = 20
print(id(x))
# Out:
# 140731586606600

# %%
x = 30

# %%
print(id(x))
# Out:
# 140731586606920

# %%
y = 20

# %%
print(id(y))
# Out:
# 140731586606600

# %%
z = y

# %%
print(id(z))
# Out:
# 140731586606600

# %%
print(z)
# Out:
# 20

# %% [markdown]
# # Operators

# %%
# + , -, * , /, //, %, **

# %%
a , b = 7, 3

# %%
print(a + b)
print(a - b)
print(a / b)  # True digision
# Out:
# 10
# 4
# 2.3333333333333335

# %%
# //  
print(a // b)
# Out:
# 2

# %%
print(a % b)
# Out:
# 1

# %%
# Exponential operator ( ** )

# %%
2 * 2
# Out:
# 4

# %%
2 ** 2
# Out:
# 4

# %%
2 ** 3
# Out:
# 8

# %%
print(a ** b)
# Out:
# 343

# %%
# Relational Operators "="

# %%
x = 20
y = 30

# %%
print(f"Is x equal to y? {x == y}")
print(f"Is x not equal to y? {x  != y}")
print(f"Is x less than y? {x < y}")
print(f"Is x greater than y? {x > y}")
print(f"Is x less than or equal to y? {x <= y}")
print(f"Is x greater than or equal to y? {x >= y}")
# Out:
# Is x equal to y? False
# Is x not equal to y? True
# Is x less than y? True
# Is x greater than y? False
# Is x less than or equal to y? True
# Is x greater than or equal to y? False

# %% [markdown]
# Keywords

# %%
import keyword

# %%
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# strings:

# %%
name = "bob"
city = "Hyderabad"

# %%
print(f"{name} lives in {city}")
# Out:
# bob lives in Hyderabad

# %%
statement1  = "she said , 'python is easy'"
statement2 = 'she said, "python is easy"'

# %%
print(statement1)
# Out:
# she said , 'python is easy'

# %%
print(statement2)
# Out:
# she said, "python is easy"

# %%
statement1  = 'she said , "python is easy"'

# %%
email ="""
Hi Bob, 

How are you :)

thank you,

Yours lovinigly 
K
"""

# %%
message = "Hello"

# %%
message
# Out:
# 'Hello'

# %%
message[0]
# Out:
# 'H'

# %%
message[1]
# Out:
# 'e'

# %%
message[0] = 'J'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 message[0] = 'J'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# Immutability => once u defined the variable with the value, u can not chagne

# %%
message = message + " World !!!"

# %%
message
# Out:
# 'Hello World !!!'

# %% [markdown]
# Slicing

# %%
word = "PYTHON"

# %%
print (word[0])
print (word[1])
print (word[2])
print (word[3])
print (word[4])
print (word[5])
print (word[6])
# Out:
# P
# Y
# T
# H
# O
# N
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[27], line 7
#       3 print (word[2])
#       4 print (word[3])
#       5 print (word[4])
#       6 print (word[5])
# ----> 7 print (word[6])
#
# IndexError: string index out of range

# %%
len(word)
# Out:
# 6

# %%
print (word[-1])
print (word[-2])
print (word[-3])
print (word[-4])
print (word[-5])
print (word[-6])
# Out:
# N
# O
# H
# T
# Y
# P

# %%
s  = "Hello World!"

# %%
s[0:4]
# Out:
# 'Hell'

# %%
s[6:11]
# Out:
# 'World'

# %%
s[6:]  # Default is the length of the string to end with
# Out:
# 'World!'

# %%
s[:5] # default is 0 to start with
# Out:
# 'Hello'

# %%
# Slicing with steps:
print(s[0:10:2])
# Out:
# HloWr

# %%
# Slicing with steps:
print(s[::2])
# Out:
# HloWrd

# %%
# Slicing with steps:
print(s[::-1])
# Out:
# !dlroW olleH

# %%
s
# Out:
# 'Hello World!'

# %%
s.upper()
# Out:
# 'HELLO WORLD!'

# %%
s.lower()
# Out:
# 'hello world!'

# %%
s.capitalize()
# Out:
# 'Hello world!'

# %%
file_name = "abc.pdf"

# %%
print(file_name.startswith(".pdf"))
# Out:
# False

# %%
print(file_name.endswith(".pdf"))
# Out:
# True

# %%
user_input = "              some input and data           "

# %%
clean_data = user_input.strip()
lclean = user_input.lstrip()
rclean = user_input.rstrip()

# %%
print(user_input)
print(clean_data)
print(lclean)
print(rclean)
# Out:
#               some input and data
# some input and data
# some input and data
#               some input and data

# %%
s = "For testing purposes, you can use dummy strings to simulate real data and test the functionality of your application. Here are some options for generating sample strings"

# %%
s.find("simulate")
# Out:
# 51

# %%
s.find("functionality")
# Out:
# 83

# %%
s.find("strings")
# Out:
# 40

# %%
s = "I like cats. Cats are cool"

# %%
nes_s = s.replace("cats", "dogs")

# %%
nes_s
# Out:
# 'I like dogs. Cats are cool'

# %%
s1 = "the quick brown, fox"
words = s1.split()
print(words)
# Out:
# ['the', 'quick', 'brown,', 'fox']

# %%
s1 = "the quick brown, fox"
words = s1.split(",")
print(words)
# Out:
# ['the quick brown', ' fox']

# %%
words_list = ['the', 'quick', 'brown', 'fox']


string2 = "".join(words_list)
string2
# Out:
# 'thequickbrownfox'

# %%
string2 = " ".join(words_list)
string2
# Out:
# 'the quick brown fox'

# %%
string2 = "<->".join(words_list)
string2
# Out:
# 'the<->quick<->brown<->fox'

# %% [markdown]
# power

# %%
string3 = "==" * 20

# %%
string3
# Out:
# '========================================'

# %%
string3 = "<=>" * 20

# %%
string3
# Out:
# '<=><=><=><=><=><=><=><=><=><=><=><=><=><=><=><=><=><=><=><=>'

# %%
str3 = "-=" * 20  # Repeat 
str3
# Out:
# '-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-='

# %%
first_name = "First Name"
lst_name = "Last Name"
full_name = first_name + " " + lst_name  # Concatenation
full_name
# Out:
# 'First Name Last Name'

# %%
# => Single line comment

"""
Multi line comment [or] doc string [or] Document String

"""
# Out:
# '\nMulti line comment [or] doc string [or] Document String\n\n'

# %%
def circle_area(radius):
    """
    This function calcuatesthe area of a circle
    
    Args:
        pas the radius of the circle in cms.
    
    It returns the area of the circle in sqare cms.
    """
    
    pi = 3.14
    
    return pi * radius * radius

# %%
help(circle_area)
# Out:
# Help on function circle_area in module __main__:
#
# circle_area(radius)
#     This function calcuatesthe area of a circle
#
#     Args:
#         pas the radius of the circle in cms.
#
#     It returns the area of the circle in sqare cms.

# %%
s = "AwesomePython"
s[7::-1]
# Out:
# 'PemosewA'

# %%
data = "alpha,beta,gamma"
parts = data.split(",")
result = "-".join(parts[1:])
result
# Out:
# 'beta-gamma'

# %%
str1 = "Madam I am adam"

# %%
str1
# Out:
# 'Madam I am adam'

# %%
str1[::-1]
# Out:
# 'mada ma I madaM'

# %%
str1[::-1]  == str1[::]
# Out:
# False

# %%
str2 = "malayalam"

# %%
str2[::]
# Out:
# 'malayalam'

# %%
str2[::-1]
# Out:
# 'malayalam'

# %%
str2[::-1]  == str2[::]
# Out:
# True

# %%
str1 = input("Name: ")
str1
# Out:
# 'Krishna'

# %%
str1 = int(input("Number: "))
str1
# Out:
# 20
