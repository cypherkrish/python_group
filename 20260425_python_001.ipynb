# %% [markdown]
# <a href="https://colab.research.google.com/github/cypherkrish/python_group/blob/main/20260425_python_001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import socket
socket.gethostbyname("www.google.com")
# Out:
# '142.251.153.119'

# %% [markdown]
# Types

# %%
age = 25
name = 'ABCDEF'
height = 3.5
is_student = True

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
print(name)
# Out:
# ABCDEF

# %%
pi = 3.14

# %%
print(pi * 3 + 5)
# Out:
# 14.42

# %% [markdown]
# f-string

# %%
name = "Krishna"
age = 90

# %%
print("My name is ", name, "and my age is: ", age)
# Out:
# My name is  Krishna and my age is:  90

# %%
print(f"My name is {name} and my age is: {age}")
# Out:
# My name is Krishna and my age is: 90

# %%
a = 10
b = 20

result = f"{a} + {b} = {a+b}"
print(result)
# Out:
# 10 + 20 = 30

# %%
pi = 3.14159265
line = f"round the pi value to 2 decimals: {pi:.2f}"
print(line)
# Out:
# round the pi value to 2 decimals: 3.14

# %%
####### => comments

# %%
# Zero padding
value = 1
line = f"Value padded to 5digits: {value:05d}"
print(line)
# Out:
# Value padded to 5digits: 00001

# %%
# Zero padding
value = 21
line = f"Value padded to 5digits: {value:05d}"
print(line)
# Out:
# Value padded to 5digits: 00021

# %%
# Zero padding
value = 321
line = f"Value padded to 5digits: {value:05d}"
print(line)
# Out:
# Value padded to 5digits: 00321

# %%
# Zero padding
value = 4321
line = f"Value padded to 5digits: {value:05d}"
print(line)
# Out:
# Value padded to 5digits: 04321

# %%
# Zero padding
value = 54321
line = f"Value padded to 5digits: {value:05d}"
print(line)
# Out:
# Value padded to 5digits: 54321

# %%
# Zero padding
value = 654321
line = f"Value padded to 5digits: {value:05d}"
print(line)
# Out:
# Value padded to 5digits: 654321

# %% [markdown]
# ## Multi line f-string or => Doc string => Document String

# %%
from_name = "Krishna"
to_name = "Krishna"

emil_body = f""" Hello {from_name}
Hello {to_name}
Hello
"""

# %%
print(emil_body)
# Out:
#  Hello Krishna
# Hello Krishna
# Hello

# %%
def sample_funciton():
    """This isa sample funciton.
    Created fortesting"""  # Doc string to explain the function

    pass

# %%
sample_funciton
# Out:
# <function __main__.sample_funciton()>

# %%
####
string = "11111111111111111111111"
string2 = """sdfsd df /n
dfsdsd n"""

# %% [markdown]
# Data Types

# %%
age = 35
temperature = -10
population  = 7900000000 # 7_900_000_000 (To imporve radability)

# %%
print(population)
# Out:
# 7900000000

# %%
price = 99.999
pi = 3.1415

# %%
# Text
name = "Python"
message = " Hello !!!!!!!"
story = """sdfdsf
sdsdfsd
sdfsfs"""

# %%
is_student = True
is_authorized = False

print(type(is_student))
print(type(is_authorized))
# Out:
# <class 'bool'>
# <class 'bool'>

# %%
print(type(age))
print(type(temperature))
print(type(population))
print(type(price))
print(type(pi))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'float'>

# %%
print(type(name))
print(type(story))
# Out:
# <class 'str'>
# <class 'str'>

# %%
character = 'c'

# %%
type(character)
# Out:
# str

# %% [markdown]
# int
# float
# str
# bool
# --------------
# list
# tuple
# dict
# set
